# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import pickle as pkl
import numpy as np

# %%
dir_path = '/Volumes/Samsung_T5/Oyla Dropbox/Oyla/02 Technical/10 Data/Oct 16 - RG visit Set 3/22_data_October_16_19_55_05//kitti/2d/'

# %%
with open(dir_path+'/rgb/yolo.pkl','rb') as fp:
    rgb = pkl.load(fp)

# %%
with open(dir_path+'/depth/yolo.pkl','rb') as fp:
    depth = pkl.load(fp)

# %%
with open(dir_path+'/ergb1/yolo.pkl','rb') as fp:
    ergb1 = pkl.load(fp)

# %%
with open(dir_path+'/ergb2/yolo.pkl','rb') as fp:
    ergb2 = pkl.load(fp)

# %%
with open(dir_path+'/ergb3/yolo.pkl','rb') as fp:
    ergb3 = pkl.load(fp)

# %%
s_rgb = 0
s_ergb1 = 0
s_ergb2 = 0
s_ergb3 = 0
s = 0
for k in sorted(rgb.keys()):
    flag = 0
    flag2 = 0
    for i in range(len(rgb[k])):
        #print(k,rgb[k][i][0],rgb[k][i][1])
        if 'person' in rgb[k][i][0]:
            s_rgb+=1
            flag += 1
#     for i in range(len(ergb1[k])):
#         #print('e1',ergb1[k][i][0],ergb1[k][i][1])
#         if 'person' in ergb1[k][i][0]:
#             s_ergb1+=1
#     for i in range(len(ergb2[k])):
#         #print('e2',ergb2[k][i][0],ergb2[k][i][1])
#         if 'person' in ergb2[k][i][0]:
#             s_ergb2+=1
    for i in range(len(ergb3[k])):
        #print('e3',ergb3[k][i][0],ergb3[k][i][1])
        if 'person' in ergb3[k][i][0]:
            s_ergb3+=1
            flag2 += 1
    if    flag >0 and flag2>0 and flag2!=flag:
        print(k,flag2,flag)
# Out:
# oyla_113.png 2 1
# oyla_114.png 3 2
# oyla_115.png 3 2
# oyla_13.png 3 2
# oyla_14.png 3 4
# oyla_150.png 2 1
# oyla_151.png 3 2
# oyla_153.png 3 2
# oyla_154.png 6 4
# oyla_157.png 2 3
# oyla_163.png 4 2
# oyla_164.png 3 2
# oyla_168.png 3 2
# oyla_169.png 5 4
# oyla_175.png 3 2
# oyla_176.png 3 2
# oyla_178.png 3 2
# oyla_179.png 2 1
# oyla_18.png 1 2
# oyla_180.png 3 2
# oyla_199.png 2 3
# oyla_200.png 2 3
# oyla_208.png 3 4
# oyla_211.png 2 1
# oyla_215.png 3 2
# oyla_216.png 3 2
# oyla_217.png 2 1
# oyla_226.png 2 1
# oyla_227.png 2 1
# oyla_232.png 2 1
# oyla_236.png 2 1
# oyla_244.png 3 2
# oyla_245.png 3 2
# oyla_254.png 4 3
# oyla_257.png 3 2
# oyla_260.png 4 3
# oyla_261.png 4 3
# oyla_265.png 4 3
# oyla_266.png 5 3
# oyla_267.png 3 2
# oyla_270.png 3 2
# oyla_271.png 3 2
# oyla_272.png 3 2
# oyla_273.png 2 3
# oyla_275.png 4 2
# oyla_276.png 4 3
# oyla_277.png 5 4
# oyla_278.png 5 4
# oyla_279.png 5 2
# oyla_280.png 5 4
# oyla_281.png 5 3
# oyla_284.png 5 4
# ...

# %%
print(s_rgb,s_ergb1,s_ergb2,s_ergb3,s)
# Out:
# 1266 0 0 1334 0

# %%
s = 0
for k in sorted(rgb.keys()):
    
    s+= len(rgb[k])
print(s)
s = 0
for k in sorted(rgb.keys()):
    
    s+= len(ergb1[k])
print(s)
s = 0
for k in sorted(rgb.keys()):
    
    s+= len(ergb2[k])
print(s)
s = 0
for k in sorted(rgb.keys()):
    
    s+= len(ergb3[k])
print(s)
# Out:
# 810
# 897
# 889
# 742

# %%
A = plt.imread(dir_path+'/rgb/oyla_208.png')

# %%
plt.imshow(A)

# %%
B = plt.imread(dir_path+'/ergb3/oyla_208.png')

# %%
plt.imshow(B)

# %%
plt.imshow(np.abs(A-B)/np.max(np.abs(A-B)))
